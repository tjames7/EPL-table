# %%
#Try and recreate EPL standings based on results
#Try to see Tottenham run of form vs other teams since November

import pandas as pd

df = pd.read_csv('C:Desktop/Datasets/EPL.csv')

df.head()
# Out:
#   Div        Date   Time        HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0  E0   12/9/2020  12:30          Fulham      Arsenal     0     3   A     0
# 1  E0   12/9/2020  15:00  Crystal Palace  Southampton     1     0   H     1
# 2  E0   12/9/2020  17:30       Liverpool        Leeds     4     3   H     3
# 3  E0   12/9/2020  20:00        West Ham    Newcastle     0     2   A     0
# 4  E0  13/09/2020  14:00       West Brom    Leicester     0     3   A     0
#
#    HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# 0     1  ...     1.84  0.75      2.01      1.89   2.02   1.91     2.13
# 1     0  ...     1.70  0.25      1.78      2.13   1.79   2.17     1.85
# 2     2  ...     2.62 -1.50      1.85      2.05   1.85   2.08     1.90
# 3     0  ...     1.92 -0.50      2.03      1.87   2.04   1.88     2.09
# 4     0  ...     1.73  0.25      1.92      1.98   1.93   1.99     1.95
#
#    MaxCAHA  AvgCAHH  AvgCAHA
# 0     1.92     2.02     1.87
# ...

# %%
df = df.rename(columns={
    'FTHG': 'HG',
    'FTAG': 'AG',
    'FTR': 'Winner'
})

df.head()
# Out:
#   Div        Date   Time        HomeTeam     AwayTeam  HG  AG Winner  HTHG  \
# 0  E0   12/9/2020  12:30          Fulham      Arsenal   0   3      A     0
# 1  E0   12/9/2020  15:00  Crystal Palace  Southampton   1   0      H     1
# 2  E0   12/9/2020  17:30       Liverpool        Leeds   4   3      H     3
# 3  E0   12/9/2020  20:00        West Ham    Newcastle   0   2      A     0
# 4  E0  13/09/2020  14:00       West Brom    Leicester   0   3      A     0
#
#    HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# 0     1  ...     1.84  0.75      2.01      1.89   2.02   1.91     2.13
# 1     0  ...     1.70  0.25      1.78      2.13   1.79   2.17     1.85
# 2     2  ...     2.62 -1.50      1.85      2.05   1.85   2.08     1.90
# 3     0  ...     1.92 -0.50      2.03      1.87   2.04   1.88     2.09
# 4     0  ...     1.73  0.25      1.92      1.98   1.93   1.99     1.95
#
#    MaxCAHA  AvgCAHH  AvgCAHA
# 0     1.92     2.02     1.87
# ...

# %%
list(df.columns.values.tolist())
# Out:
# ['Div',
#  'Date',
#  'Time',
#  'HomeTeam',
#  'AwayTeam',
#  'HG',
#  'AG',
#  'Winner',
#  'HTHG',
#  'HTAG',
#  'HTR',
#  'Referee',
#  'HS',
#  'AS',
#  'HST',
#  'AST',
#  'HF',
#  'AF',
#  'HC',
#  'AC',
#  'HY',
#  'AY',
#  'HR',
#  'AR',
#  'B365H',
#  'B365D',
#  'B365A',
#  'BWH',
#  'BWD',
#  'BWA',
#  'IWH',
#  'IWD',
#  'IWA',
#  'PSH',
#  'PSD',
#  'PSA',
#  'WHH',
#  'WHD',
#  'WHA',
#  'VCH',
#  'VCD',
#  'VCA',
#  'MaxH',
#  'MaxD',
#  'MaxA',
#  'AvgH',
#  'AvgD',
#  'AvgA',
#  'B365>2.5',
#  'B365<2.5',
#  'P>2.5',
#  'P<2.5',
#  'Max>2.5',
#  'Max<2.5',
#  'Avg>2.5',
#  'Avg<2.5',
#  'AHh',
#  'B365AHH',
#  'B365AHA',
#  'PAHH',
#  'PAHA',
#  'MaxAHH',
#  'MaxAHA',
#  'AvgAHH',
#  'AvgAHA',
#  'B365CH',
#  'B365CD',
#  'B365CA',
#  'BWCH',
#  'BWCD',
#  'BWCA',
#  'IWCH',
#  'IWCD',
#  'IWCA',
#  'PSCH',
#  'PSCD',
#  'PSCA',
#  'WHCH',
#  'WHCD',
#  'WHCA',
#  'VCCH',
#  'VCCD',
#  'VCCA',
#  'MaxCH',
#  'MaxCD',
#  'MaxCA',
#  'AvgCH',
#  'AvgCD',
#  'AvgCA',
# ...

# %%
df.drop(['Div', 'HTHG', 'HTAG', 'HTR', 'Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY', 'AY', 'HR', 'AR', 
         'B365H', 'B365D', 'B365A', 'BWH', 'BWD', 'BWA', 'IWH', 'IWD', 'IWA', 'PSH', 'PSD', 'PSA', 'WHH', 'WHD', 'WHA', 'VCH',
         'VCD', 'VCA', 'MaxH', 'MaxD', 'MaxA', 'AvgH', 'AvgD', 'AvgA', 'B365>2.5', 'B365<2.5', 'P>2.5', 'P<2.5', 'Max>2.5',
         'Max<2.5', 'Avg>2.5', 'Avg<2.5', 'AHh', 'B365AHH', 'B365AHA', 'PAHH', 'PAHA', 'MaxAHH', 'MaxAHA', 'AvgAHH', 'AvgAHA',
         'B365CH', 'B365CD', 'B365CA', 'BWCH', 'BWCD', 'BWCA', 'IWCH', 'IWCD', 'IWCA', 'PSCH', 'PSCD', 'PSCA', 'WHCH', 'WHCD',
         'WHCA', 'VCCH', 'VCCD', 'VCCA', 'MaxCH', 'MaxCD', 'MaxCA', 'AvgCH', 'AvgCD', 'AvgCA', 'B365C>2.5', 'B365C<2.5',
         'PC>2.5', 'PC<2.5', 'MaxC>2.5', 'MaxC<2.5', 'AvgC>2.5', 'AvgC<2.5', 'AHCh', 'B365CAHH', 'B365CAHA', 'PCAHH', 'PCAHA',
         'MaxCAHH', 'MaxCAHA', 'AvgCAHH', 'AvgCAHA', 'Time'], axis=1, inplace=True)


df.head()
# Out:
#          Date        HomeTeam     AwayTeam  HG  AG Winner
# 0   12/9/2020          Fulham      Arsenal   0   3      A
# 1   12/9/2020  Crystal Palace  Southampton   1   0      H
# 2   12/9/2020       Liverpool        Leeds   4   3      H
# 3   12/9/2020        West Ham    Newcastle   0   2      A
# 4  13/09/2020       West Brom    Leicester   0   3      A

# %%
df['Date'] = pd.to_datetime(df['Date'], dayfirst=True).dt.strftime('%m-%d-%Y')

df
# Out:
#            Date          HomeTeam          AwayTeam  HG  AG Winner
# 0    09-12-2020            Fulham           Arsenal   0   3      A
# 1    09-12-2020    Crystal Palace       Southampton   1   0      H
# 2    09-12-2020         Liverpool             Leeds   4   3      H
# 3    09-12-2020          West Ham         Newcastle   0   2      A
# 4    09-13-2020         West Brom         Leicester   0   3      A
# 5    09-13-2020         Tottenham           Everton   0   1      A
# 6    09-14-2020          Brighton           Chelsea   1   3      A
# 7    09-14-2020  Sheffield United            Wolves   0   2      A
# 8    09-19-2020           Everton         West Brom   5   2      H
# 9    09-19-2020             Leeds            Fulham   4   3      H
# 10   09-19-2020        Man United    Crystal Palace   1   3      A
# 11   09-19-2020           Arsenal          West Ham   2   1      H
# 12   09-20-2020       Southampton         Tottenham   2   5      A
# ...

# %%
df['HomeTeam'].unique()
# Out:
# array(['Fulham', 'Crystal Palace', 'Liverpool', 'West Ham', 'West Brom',
#        'Tottenham', 'Brighton', 'Sheffield United', 'Everton', 'Leeds',
#        'Man United', 'Arsenal', 'Southampton', 'Newcastle', 'Chelsea',
#        'Leicester', 'Aston Villa', 'Wolves', 'Burnley', 'Man City'],
#       dtype=object)

# %%
df_tottenham = df.loc[(df['HomeTeam'] == 'Tottenham') | (df['AwayTeam'] == 'Tottenham')]

df_tottenham.head()
# Out:
#           Date     HomeTeam   AwayTeam  HG  AG Winner
# 5   09-13-2020    Tottenham    Everton   0   1      A
# 12  09-20-2020  Southampton  Tottenham   2   5      A
# 23  09-27-2020    Tottenham  Newcastle   1   1      D
# 36  10-04-2020   Man United  Tottenham   1   6      A
# 44  10-18-2020    Tottenham   West Ham   3   3      D

# %%
df_tottenham.loc[(df_tottenham['HomeTeam'] == 'Tottenham') & 
                 (df_tottenham['Winner'] == 'H'), 'Points'] = 3
df_tottenham.loc[(df_tottenham['AwayTeam'] == 'Tottenham') & 
                 (df_tottenham['Winner'] == 'A'), 'Points'] = 3
df_tottenham.loc[(df_tottenham['HomeTeam'] == 'Tottenham') & 
                 (df_tottenham['Winner'] == 'A'), 'Points'] = 0
df_tottenham.loc[(df_tottenham['AwayTeam'] == 'Tottenham') & 
                 (df_tottenham['Winner'] == 'H'), 'Points'] = 0
df_tottenham.loc[(df_tottenham['HomeTeam'] == 'Tottenham') & 
                 (df_tottenham['Winner'] == 'D'), 'Points'] = 1
df_tottenham.loc[(df_tottenham['AwayTeam'] == 'Tottenham') & 
                 (df_tottenham['Winner'] == 'D'), 'Points'] = 1

df_tottenham
# Out:
# C:\Users\tjame\Anaconda3\lib\site-packages\pandas\core\indexing.py:362: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\tjame\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
#            Date          HomeTeam   AwayTeam  HG  AG Winner  Points
# 5    09-13-2020         Tottenham    Everton   0   1      A     0.0
# 12   09-20-2020       Southampton  Tottenham   2   5      A     3.0
# ...

# %%
# import numpy as np

# def points(c):
#     if c['HomeTeam'] == 'Tottenham' and c['Winner'] == 'H':
#         return 3
#     elif c['AwayTeam'] == 'Tottenham' and c['Winner'] == 'A':
#         return 3
#     elif c['HomeTeam'] == 'Tottenham' and c['Winner'] == 'A':
#         return 0
#     elif c['AwayTeam'] == 'Tottenham' and c['Winner'] == 'H':
#         return 0
#     else:
#         return 1

# def points(tdf, team):
#     if (tdf.loc[(tdf['HomeTeam'] == team)]) & (tdf.loc[(tdf['Winner'] == 'H')]):
#         return 3
#     elif (tdf.loc[(tdf['AwayTeam'] == team)]) & (tdf.loc[(tdf['Winner'] == 'A')]):
#         return 3
#     elif (tdf.loc[(tdf['HomeTeam'] == team)]) & (tdf.loc[(tdf['Winner'] == 'A')]):
#         return 0
#     elif (tdf.loc[(tdf['AwayTeam'] == team)]) & (tdf.loc[(tdf['Winner'] == 'H')]):
#         return 0
#     else:
#         return 1

# def Points(tdf, team):
#     tdf.loc[(tdf['HomeTeam'] == team) & 
#             (tdf['Winner'] == 'H'), 'Points'] = 3
#     tdf.loc[(tdf['AwayTeam'] == team) & 
#             (tdf['Winner'] == 'A'), 'Points'] = 3
#     tdf.loc[(tdf['HomeTeam'] == team) & 
#             (tdf['Winner'] == 'A'), 'Points'] = 0
#     tdf.loc[(tdf['AwayTeam'] == team) & 
#             (tdf['Winner'] == 'H'), 'Points'] = 0
#     tdf.loc[(tdf['HomeTeam'] == team) & 
#             (tdf['Winner'] == 'D'), 'Points'] = 1
#     tdf.loc[(tdf['AwayTeam'] == team) & 
#             (tdf['Winner'] == 'D'), 'Points'] = 1
    
# def Points(tdf):
#     if tdf.loc[(tdf['HomeTeam'] == "Tottenham") & (tdf['Winner'] == 'H'), 'Points']:
#         return 3
#     elif tdf.loc[(tdf['AwayTeam'] == "Tottenham") & (tdf['Winner'] == 'A'), 'Points']:
#         return 3
#     elif tdf.loc[(tdf['HomeTeam'] == "Tottenham") & (tdf['Winner'] == 'A'), 'Points']:
#         return 0
#     elif tdf.loc[(tdf['AwayTeam'] == "Tottenham") & (tdf['Winner'] == 'H'), 'Points']:
#         return 0
#     elif tdf.loc[(tdf['HomeTeam'] == "Tottenham") & (tdf['Winner'] == 'D'), 'Points']:
#         return 1
#     elif tdf.loc[(tdf['AwayTeam'] == "Tottenham") & (tdf['Winner'] == 'D'), 'Points']:
#         return 1    
    
# df_tottenham.loc[(df_tottenham['HomeTeam'] == 'Tottenham') & 
#                  (df_tottenham['Winner'] == 'H'), 'Points'] = 3
# df_tottenham.loc[(df_tottenham['AwayTeam'] == 'Tottenham') & 
#                  (df_tottenham['Winner'] == 'A'), 'Points'] = 3
# df_tottenham.loc[(df_tottenham['HomeTeam'] == 'Tottenham') & 
#                  (df_tottenham['Winner'] == 'A'), 'Points'] = 0
# df_tottenham.loc[(df_tottenham['AwayTeam'] == 'Tottenham') & 
#                  (df_tottenham['Winner'] == 'H'), 'Points'] = 0
# df_tottenham.loc[(df_tottenham['HomeTeam'] == 'Tottenham') & 
#                  (df_tottenham['Winner'] == 'D'), 'Points'] = 1
# df_tottenham.loc[(df_tottenham['AwayTeam'] == 'Tottenham') & 
#                  (df_tottenham['Winner'] == 'D'), 'Points'] = 1

# df_tottenham['Points'] = df.apply(points, axis=1)

# df_tottenham['Points'] = df.apply(Points(df_tottenham, 'Tottenham'), axis=1)

# conditions = [
#     (df_tottenham['HomeTeam'] == 'Tottenham') & (df_tottenham['Winner'] == 'H'),
#     (df_tottenham['AwayTeam'] == 'Tottenham') & (df_tottenham['Winner'] == 'A'),
#     (df_tottenham['HomeTeam'] == 'Tottenham') & (df_tottenham['Winner'] == 'A'),
#     (df_tottenham['AwayTeam'] == 'Tottenham') & (df_tottenham['Winner'] == 'H'),
#     (df_tottenham['HomeTeam'] == 'Tottenham') & (df_tottenham['Winner'] == 'D'),
#     (df_tottenham['AwayTeam'] == 'Tottenham') & (df_tottenham['Winner'] == 'D')
# ]
# results = [3,3,0,0,1,1]

# df_tottenham['Points'] = np.select(conditions,results)

# df_tottenham

# %%
tottenhampoints = df_tottenham['Points'].sum()
tottenhampoints
# Out:
# 33.0

# %%
df_mancity = df.loc[(df['HomeTeam'] == 'Man City') | (df['AwayTeam'] == 'Man City')]
df_fulham = df.loc[(df['HomeTeam'] == 'Fulham') | (df['AwayTeam'] == 'Fulham')]
df_cp = df.loc[(df['HomeTeam'] == 'Crystal Palace') | (df['AwayTeam'] == 'Crystal Palace')]
df_liverpool = df.loc[(df['HomeTeam'] == 'Liverpool') | (df['AwayTeam'] == 'Liverpool')]
df_wh = df.loc[(df['HomeTeam'] == 'West Ham') | (df['AwayTeam'] == 'West Ham')]
df_wb = df.loc[(df['HomeTeam'] == 'West Brom') | (df['AwayTeam'] == 'West Brom')]
df_brighton = df.loc[(df['HomeTeam'] == 'Brighton') | (df['AwayTeam'] == 'Brighton')]
df_sheffield = df.loc[(df['HomeTeam'] == 'Sheffield United') | (df['AwayTeam'] == 'Sheffield United')]
df_everton = df.loc[(df['HomeTeam'] == 'Everton') | (df['AwayTeam'] == 'Everton')]
df_leeds = df.loc[(df['HomeTeam'] == 'Leeds') | (df['AwayTeam'] == 'Leeds')]
df_manu = df.loc[(df['HomeTeam'] == 'Man United') | (df['AwayTeam'] == 'Man United')]
df_arsenal = df.loc[(df['HomeTeam'] == 'Arsenal') | (df['AwayTeam'] == 'Arsenal')]
df_soton = df.loc[(df['HomeTeam'] == 'Southampton') | (df['AwayTeam'] == 'Southampton')]
df_newcastle = df.loc[(df['HomeTeam'] == 'Newcastle') | (df['AwayTeam'] == 'Newcastle')]
df_chelsea = df.loc[(df['HomeTeam'] == 'Chelsea') | (df['AwayTeam'] == 'Chelsea')]
df_leicester = df.loc[(df['HomeTeam'] == 'Leicester') | (df['AwayTeam'] == 'Leicester')]
df_av = df.loc[(df['HomeTeam'] == 'Aston Villa') | (df['AwayTeam'] == 'Aston Villa')]
df_wolves = df.loc[(df['HomeTeam'] == 'Wolves') | (df['AwayTeam'] == 'Wolves')]
df_burnley = df.loc[(df['HomeTeam'] == 'Burnley') | (df['AwayTeam'] == 'Burnley')]

#How use points function above for all teams here?

# %%
df_mancity.loc[(df_mancity['HomeTeam'] == 'Man City') & 
               (df_mancity['Winner'] == 'H'), 'Points'] = 3
df_mancity.loc[(df_mancity['AwayTeam'] == 'Man City') & 
               (df_mancity['Winner'] == 'A'), 'Points'] = 3
df_mancity.loc[(df_mancity['HomeTeam'] == 'Man City') & 
               (df_mancity['Winner'] == 'A'), 'Points'] = 0
df_mancity.loc[(df_mancity['AwayTeam'] == 'Man City') & 
               (df_mancity['Winner'] == 'H'), 'Points'] = 0
df_mancity.loc[(df_mancity['HomeTeam'] == 'Man City') & 
               (df_mancity['Winner'] == 'D'), 'Points'] = 1
df_mancity.loc[(df_mancity['AwayTeam'] == 'Man City') & 
               (df_mancity['Winner'] == 'D'), 'Points'] = 1

# def points(c):
#     if c['HomeTeam'] == 'Man City' and c['Winner'] == 'H':
#         return 3
#     elif c['AwayTeam'] == 'Man City' and c['Winner'] == 'A':
#         return 3
#     elif c['HomeTeam'] == 'Man City' and c['Winner'] == 'A':
#         return 0
#     elif c['AwayTeam'] == 'Man City' and c['Winner'] == 'H':
#         return 0
#     else:
#         return 1
    
# df_mancity['Points'] = df.apply(points, axis=1)

df_mancity
# Out:
#            Date          HomeTeam          AwayTeam  HG  AG Winner  Points
# 17   09-21-2020            Wolves          Man City   1   3      A     3.0
# 24   09-27-2020          Man City         Leicester   2   5      A     0.0
# 30   10-03-2020             Leeds          Man City   1   1      D     1.0
# 40   10-17-2020          Man City           Arsenal   1   0      H     3.0
# 49   10-24-2020          West Ham          Man City   1   1      D     1.0
# 59   10-31-2020  Sheffield United          Man City   0   1      A     3.0
# 76   11-08-2020          Man City         Liverpool   1   1      D     1.0
# 80   11-21-2020         Tottenham          Man City   2   0      H     0.0
# 90   11-28-2020          Man City           Burnley   5   0      H     3.0
# 99   12-05-2020          Man City            Fulham   2   0      H     3.0
# 110  12-12-2020        Man United          Man City   0   0      D     1.0
# ...

# %%
mancitypoints = df_mancity['Points'].sum()
mancitypoints
# Out:
# 44.0

# %%
df_fulham.loc[(df_fulham['HomeTeam'] == 'Fulham') & 
              (df_fulham['Winner'] == 'H'), 'Points'] = 3
df_fulham.loc[(df_fulham['AwayTeam'] == 'Fulham') & 
              (df_fulham['Winner'] == 'A'), 'Points'] = 3
df_fulham.loc[(df_fulham['HomeTeam'] == 'Fulham') & 
              (df_fulham['Winner'] == 'A'), 'Points'] = 0
df_fulham.loc[(df_fulham['AwayTeam'] == 'Fulham') & 
              (df_fulham['Winner'] == 'H'), 'Points'] = 0
df_fulham.loc[(df_fulham['HomeTeam'] == 'Fulham') & 
              (df_fulham['Winner'] == 'D'), 'Points'] = 1
df_fulham.loc[(df_fulham['AwayTeam'] == 'Fulham') & 
              (df_fulham['Winner'] == 'D'), 'Points'] = 1

fulhampoints = df_fulham['Points'].sum()

# %%
df_cp.loc[(df_cp['HomeTeam'] == 'Crystal Palace') & 
                 (df_cp['Winner'] == 'H'), 'Points'] = 3
df_cp.loc[(df_cp['AwayTeam'] == 'Crystal Palace') & 
                 (df_cp['Winner'] == 'A'), 'Points'] = 3
df_cp.loc[(df_cp['HomeTeam'] == 'Crystal Palace') & 
                 (df_cp['Winner'] == 'A'), 'Points'] = 0
df_cp.loc[(df_cp['AwayTeam'] == 'Crystal Palace') & 
                 (df_cp['Winner'] == 'H'), 'Points'] = 0
df_cp.loc[(df_cp['HomeTeam'] == 'Crystal Palace') & 
                 (df_cp['Winner'] == 'D'), 'Points'] = 1
df_cp.loc[(df_cp['AwayTeam'] == 'Crystal Palace') & 
                 (df_cp['Winner'] == 'D'), 'Points'] = 1
    
cppoints = df_cp['Points'].sum()

# %%
df_liverpool.loc[(df_liverpool['HomeTeam'] == 'Liverpool') & 
                 (df_liverpool['Winner'] == 'H'), 'Points'] = 3
df_liverpool.loc[(df_liverpool['AwayTeam'] == 'Liverpool') & 
                 (df_liverpool['Winner'] == 'A'), 'Points'] = 3
df_liverpool.loc[(df_liverpool['HomeTeam'] == 'Liverpool') & 
                 (df_liverpool['Winner'] == 'A'), 'Points'] = 0
df_liverpool.loc[(df_liverpool['AwayTeam'] == 'Liverpool') & 
                 (df_liverpool['Winner'] == 'H'), 'Points'] = 0
df_liverpool.loc[(df_liverpool['HomeTeam'] == 'Liverpool') & 
                 (df_liverpool['Winner'] == 'D'), 'Points'] = 1
df_liverpool.loc[(df_liverpool['AwayTeam'] == 'Liverpool') & 
                 (df_liverpool['Winner'] == 'D'), 'Points'] = 1

liverpoolpoints = df_liverpool['Points'].sum()

# %%
df_wh.loc[(df_wh['HomeTeam'] == 'West Ham') & 
                 (df_wh['Winner'] == 'H'), 'Points'] = 3
df_wh.loc[(df_wh['AwayTeam'] == 'West Ham') & 
                 (df_wh['Winner'] == 'A'), 'Points'] = 3
df_wh.loc[(df_wh['HomeTeam'] == 'West Ham') & 
                 (df_wh['Winner'] == 'A'), 'Points'] = 0
df_wh.loc[(df_wh['AwayTeam'] == 'West Ham') & 
                 (df_wh['Winner'] == 'H'), 'Points'] = 0
df_wh.loc[(df_wh['HomeTeam'] == 'West Ham') & 
                 (df_wh['Winner'] == 'D'), 'Points'] = 1
df_wh.loc[(df_wh['AwayTeam'] == 'West Ham') & 
                 (df_wh['Winner'] == 'D'), 'Points'] = 1

whpoints = df_wh['Points'].sum()

# %%
df_wb.loc[(df_wb['HomeTeam'] == 'West Brom') & 
                 (df_wb['Winner'] == 'H'), 'Points'] = 3
df_wb.loc[(df_wb['AwayTeam'] == 'West Brom') & 
                 (df_wb['Winner'] == 'A'), 'Points'] = 3
df_wb.loc[(df_wb['HomeTeam'] == 'West Brom') & 
                 (df_wb['Winner'] == 'A'), 'Points'] = 0
df_wb.loc[(df_wb['AwayTeam'] == 'West Brom') & 
                 (df_wb['Winner'] == 'H'), 'Points'] = 0
df_wb.loc[(df_wb['HomeTeam'] == 'West Brom') & 
                 (df_wb['Winner'] == 'D'), 'Points'] = 1
df_wb.loc[(df_wb['AwayTeam'] == 'West Brom') & 
                 (df_wb['Winner'] == 'D'), 'Points'] = 1

wbpoints = df_wb['Points'].sum()

# %%
df_brighton.loc[(df_brighton['HomeTeam'] == 'Brighton') & 
                 (df_brighton['Winner'] == 'H'), 'Points'] = 3
df_brighton.loc[(df_brighton['AwayTeam'] == 'Brighton') & 
                 (df_brighton['Winner'] == 'A'), 'Points'] = 3
df_brighton.loc[(df_brighton['HomeTeam'] == 'Brighton') & 
                 (df_brighton['Winner'] == 'A'), 'Points'] = 0
df_brighton.loc[(df_brighton['AwayTeam'] == 'Brighton') & 
                 (df_brighton['Winner'] == 'H'), 'Points'] = 0
df_brighton.loc[(df_brighton['HomeTeam'] == 'Brighton') & 
                 (df_brighton['Winner'] == 'D'), 'Points'] = 1
df_brighton.loc[(df_brighton['AwayTeam'] == 'Brighton') & 
                 (df_brighton['Winner'] == 'D'), 'Points'] = 1
    
brightonpoints = df_brighton['Points'].sum()

# %%
df_sheffield.loc[(df_sheffield['HomeTeam'] == 'Sheffield United') & 
                 (df_sheffield['Winner'] == 'H'), 'Points'] = 3
df_sheffield.loc[(df_sheffield['AwayTeam'] == 'Sheffield United') & 
                 (df_sheffield['Winner'] == 'A'), 'Points'] = 3
df_sheffield.loc[(df_sheffield['HomeTeam'] == 'Sheffield United') & 
                 (df_sheffield['Winner'] == 'A'), 'Points'] = 0
df_sheffield.loc[(df_sheffield['AwayTeam'] == 'Sheffield United') & 
                 (df_sheffield['Winner'] == 'H'), 'Points'] = 0
df_sheffield.loc[(df_sheffield['HomeTeam'] == 'Sheffield United') & 
                 (df_sheffield['Winner'] == 'D'), 'Points'] = 1
df_sheffield.loc[(df_sheffield['AwayTeam'] == 'Sheffield United') & 
                 (df_sheffield['Winner'] == 'D'), 'Points'] = 1
    
sheffieldpoints = df_sheffield['Points'].sum()

# %%
df_everton.loc[(df_everton['HomeTeam'] == 'Everton') & 
                 (df_everton['Winner'] == 'H'), 'Points'] = 3
df_everton.loc[(df_everton['AwayTeam'] == 'Everton') & 
                 (df_everton['Winner'] == 'A'), 'Points'] = 3
df_everton.loc[(df_everton['HomeTeam'] == 'Everton') & 
                 (df_everton['Winner'] == 'A'), 'Points'] = 0
df_everton.loc[(df_everton['AwayTeam'] == 'Everton') & 
                 (df_everton['Winner'] == 'H'), 'Points'] = 0
df_everton.loc[(df_everton['HomeTeam'] == 'Everton') & 
                 (df_everton['Winner'] == 'D'), 'Points'] = 1
df_everton.loc[(df_everton['AwayTeam'] == 'Everton') & 
                 (df_everton['Winner'] == 'D'), 'Points'] = 1
    
evertonpoints = df_everton['Points'].sum()

# %%
df_leeds.loc[(df_leeds['HomeTeam'] == 'Leeds') & 
             (df_leeds['Winner'] == 'H'), 'Points'] = 3
df_leeds.loc[(df_leeds['AwayTeam'] == 'Leeds') & 
             (df_leeds['Winner'] == 'A'), 'Points'] = 3
df_leeds.loc[(df_leeds['HomeTeam'] == 'Leeds') & 
             (df_leeds['Winner'] == 'A'), 'Points'] = 0
df_leeds.loc[(df_leeds['AwayTeam'] == 'Leeds') & 
             (df_leeds['Winner'] == 'H'), 'Points'] = 0
df_leeds.loc[(df_leeds['HomeTeam'] == 'Leeds') & 
             (df_leeds['Winner'] == 'D'), 'Points'] = 1
df_leeds.loc[(df_leeds['AwayTeam'] == 'Leeds') & 
             (df_leeds['Winner'] == 'D'), 'Points'] = 1
    
leedspoints = df_leeds['Points'].sum()

# %%
df_manu.loc[(df_manu['HomeTeam'] == 'Man United') & 
             (df_manu['Winner'] == 'H'), 'Points'] = 3
df_manu.loc[(df_manu['AwayTeam'] == 'Man United') & 
             (df_manu['Winner'] == 'A'), 'Points'] = 3
df_manu.loc[(df_manu['HomeTeam'] == 'Man United') & 
             (df_manu['Winner'] == 'A'), 'Points'] = 0
df_manu.loc[(df_manu['AwayTeam'] == 'Man United') & 
             (df_manu['Winner'] == 'H'), 'Points'] = 0
df_manu.loc[(df_manu['HomeTeam'] == 'Man United') & 
             (df_manu['Winner'] == 'D'), 'Points'] = 1
df_manu.loc[(df_manu['AwayTeam'] == 'Man United') & 
             (df_manu['Winner'] == 'D'), 'Points'] = 1
    
manupoints = df_manu['Points'].sum()

# %%
df_arsenal.loc[(df_arsenal['HomeTeam'] == 'Arsenal') & 
             (df_arsenal['Winner'] == 'H'), 'Points'] = 3
df_arsenal.loc[(df_arsenal['AwayTeam'] == 'Arsenal') & 
             (df_arsenal['Winner'] == 'A'), 'Points'] = 3
df_arsenal.loc[(df_arsenal['HomeTeam'] == 'Arsenal') & 
             (df_arsenal['Winner'] == 'A'), 'Points'] = 0
df_arsenal.loc[(df_arsenal['AwayTeam'] == 'Arsenal') & 
             (df_arsenal['Winner'] == 'H'), 'Points'] = 0
df_arsenal.loc[(df_arsenal['HomeTeam'] == 'Arsenal') & 
             (df_arsenal['Winner'] == 'D'), 'Points'] = 1
df_arsenal.loc[(df_arsenal['AwayTeam'] == 'Arsenal') & 
             (df_arsenal['Winner'] == 'D'), 'Points'] = 1
    
arsenalpoints = df_arsenal['Points'].sum()

# %%
df_soton.loc[(df_soton['HomeTeam'] == 'Southampton') & 
             (df_soton['Winner'] == 'H'), 'Points'] = 3
df_soton.loc[(df_soton['AwayTeam'] == 'Southampton') & 
             (df_soton['Winner'] == 'A'), 'Points'] = 3
df_soton.loc[(df_soton['HomeTeam'] == 'Southampton') & 
             (df_soton['Winner'] == 'A'), 'Points'] = 0
df_soton.loc[(df_soton['AwayTeam'] == 'Southampton') & 
             (df_soton['Winner'] == 'H'), 'Points'] = 0
df_soton.loc[(df_soton['HomeTeam'] == 'Southampton') & 
             (df_soton['Winner'] == 'D'), 'Points'] = 1
df_soton.loc[(df_soton['AwayTeam'] == 'Southampton') & 
             (df_soton['Winner'] == 'D'), 'Points'] = 1
    
sotonpoints = df_soton['Points'].sum()

# %%
df_newcastle.loc[(df_newcastle['HomeTeam'] == 'Newcastle') & 
                 (df_newcastle['Winner'] == 'H'), 'Points'] = 3
df_newcastle.loc[(df_newcastle['AwayTeam'] == 'Newcastle') & 
                 (df_newcastle['Winner'] == 'A'), 'Points'] = 3
df_newcastle.loc[(df_newcastle['HomeTeam'] == 'Newcastle') & 
                 (df_newcastle['Winner'] == 'A'), 'Points'] = 0
df_newcastle.loc[(df_newcastle['AwayTeam'] == 'Newcastle') & 
                 (df_newcastle['Winner'] == 'H'), 'Points'] = 0
df_newcastle.loc[(df_newcastle['HomeTeam'] == 'Newcastle') & 
                 (df_newcastle['Winner'] == 'D'), 'Points'] = 1
df_newcastle.loc[(df_newcastle['AwayTeam'] == 'Newcastle') & 
                 (df_newcastle['Winner'] == 'D'), 'Points'] = 1
    
newcastlepoints = df_newcastle['Points'].sum()

# %%
df_chelsea.loc[(df_chelsea['HomeTeam'] == 'Chelsea') & 
               (df_chelsea['Winner'] == 'H'), 'Points'] = 3
df_chelsea.loc[(df_chelsea['AwayTeam'] == 'Chelsea') & 
               (df_chelsea['Winner'] == 'A'), 'Points'] = 3
df_chelsea.loc[(df_chelsea['HomeTeam'] == 'Chelsea') & 
               (df_chelsea['Winner'] == 'A'), 'Points'] = 0
df_chelsea.loc[(df_chelsea['AwayTeam'] == 'Chelsea') & 
               (df_chelsea['Winner'] == 'H'), 'Points'] = 0
df_chelsea.loc[(df_chelsea['HomeTeam'] == 'Chelsea') & 
               (df_chelsea['Winner'] == 'D'), 'Points'] = 1
df_chelsea.loc[(df_chelsea['AwayTeam'] == 'Chelsea') & 
               (df_chelsea['Winner'] == 'D'), 'Points'] = 1

chelseapoints = df_chelsea['Points'].sum()

# %%
df_leicester.loc[(df_leicester['HomeTeam'] == 'Leicester') & 
               (df_leicester['Winner'] == 'H'), 'Points'] = 3
df_leicester.loc[(df_leicester['AwayTeam'] == 'Leicester') & 
               (df_leicester['Winner'] == 'A'), 'Points'] = 3
df_leicester.loc[(df_leicester['HomeTeam'] == 'Leicester') & 
               (df_leicester['Winner'] == 'A'), 'Points'] = 0
df_leicester.loc[(df_leicester['AwayTeam'] == 'Leicester') & 
               (df_leicester['Winner'] == 'H'), 'Points'] = 0
df_leicester.loc[(df_leicester['HomeTeam'] == 'Leicester') & 
               (df_leicester['Winner'] == 'D'), 'Points'] = 1
df_leicester.loc[(df_leicester['AwayTeam'] == 'Leicester') & 
               (df_leicester['Winner'] == 'D'), 'Points'] = 1
    
leicesterpoints = df_leicester['Points'].sum()

# %%
df_av.loc[(df_av['HomeTeam'] == 'Aston Villa') & 
               (df_av['Winner'] == 'H'), 'Points'] = 3
df_av.loc[(df_av['AwayTeam'] == 'Aston Villa') & 
               (df_av['Winner'] == 'A'), 'Points'] = 3
df_av.loc[(df_av['HomeTeam'] == 'Aston Villa') & 
               (df_av['Winner'] == 'A'), 'Points'] = 0
df_av.loc[(df_av['AwayTeam'] == 'Aston Villa') & 
               (df_av['Winner'] == 'H'), 'Points'] = 0
df_av.loc[(df_av['HomeTeam'] == 'Aston Villa') & 
               (df_av['Winner'] == 'D'), 'Points'] = 1
df_av.loc[(df_av['AwayTeam'] == 'Aston Villa') & 
               (df_av['Winner'] == 'D'), 'Points'] = 1
    
avpoints = df_av['Points'].sum()

# %%
df_wolves.loc[(df_wolves['HomeTeam'] == 'Wolves') & 
               (df_wolves['Winner'] == 'H'), 'Points'] = 3
df_wolves.loc[(df_wolves['AwayTeam'] == 'Wolves') & 
               (df_wolves['Winner'] == 'A'), 'Points'] = 3
df_wolves.loc[(df_wolves['HomeTeam'] == 'Wolves') & 
               (df_wolves['Winner'] == 'A'), 'Points'] = 0
df_wolves.loc[(df_wolves['AwayTeam'] == 'Wolves') & 
               (df_wolves['Winner'] == 'H'), 'Points'] = 0
df_wolves.loc[(df_wolves['HomeTeam'] == 'Wolves') & 
               (df_wolves['Winner'] == 'D'), 'Points'] = 1
df_wolves.loc[(df_wolves['AwayTeam'] == 'Wolves') & 
               (df_wolves['Winner'] == 'D'), 'Points'] = 1
    
wolvespoints = df_wolves['Points'].sum()

# %%
df_burnley.loc[(df_burnley['HomeTeam'] == 'Burnley') & 
               (df_burnley['Winner'] == 'H'), 'Points'] = 3
df_burnley.loc[(df_burnley['AwayTeam'] == 'Burnley') & 
               (df_burnley['Winner'] == 'A'), 'Points'] = 3
df_burnley.loc[(df_burnley['HomeTeam'] == 'Burnley') & 
               (df_burnley['Winner'] == 'A'), 'Points'] = 0
df_burnley.loc[(df_burnley['AwayTeam'] == 'Burnley') & 
               (df_burnley['Winner'] == 'H'), 'Points'] = 0
df_burnley.loc[(df_burnley['HomeTeam'] == 'Burnley') & 
               (df_burnley['Winner'] == 'D'), 'Points'] = 1
df_burnley.loc[(df_burnley['AwayTeam'] == 'Burnley') & 
               (df_burnley['Winner'] == 'D'), 'Points'] = 1

burnleypoints = df_burnley['Points'].sum()

# %%
d = {'Teams': ['Fulham', 'Crystal Palace', 'Liverpool', 'West Ham', 'West Brom',
       'Tottenham', 'Brighton', 'Sheffield United', 'Everton', 'Leeds',
       'Man United', 'Arsenal', 'Southampton', 'Newcastle', 'Chelsea',
       'Leicester', 'Aston Villa', 'Wolves', 'Burnley', 'Man City'], 
     'Points': [fulhampoints, cppoints, liverpoolpoints, whpoints, wbpoints,
               tottenhampoints, brightonpoints, sheffieldpoints, evertonpoints, leedspoints,
               manupoints, arsenalpoints, sotonpoints, newcastlepoints, chelseapoints,
               leicesterpoints, avpoints, wolvespoints, burnleypoints, mancitypoints]}
df_epltable = pd.DataFrame(data=d)
df_epltable
# Out:
#                Teams  Points
# 0             Fulham    14.0
# 1     Crystal Palace    26.0
# 2          Liverpool    40.0
# 3           West Ham    35.0
# 4          West Brom    12.0
# 5          Tottenham    33.0
# 6           Brighton    21.0
# 7   Sheffield United     8.0
# 8            Everton    33.0
# 9              Leeds    29.0
# 10        Man United    41.0
# 11           Arsenal    31.0
# 12       Southampton    29.0
# 13         Newcastle    22.0
# 14           Chelsea    33.0
# 15         Leicester    39.0
# 16       Aston Villa    32.0
# 17            Wolves    23.0
# 18           Burnley    22.0
# 19          Man City    44.0

# %%
df_epltable.sort_values(by=['Points'], ascending=False)
# Out:
#                Teams  Points
# 19          Man City    44.0
# 10        Man United    41.0
# 2          Liverpool    40.0
# 15         Leicester    39.0
# 3           West Ham    35.0
# 5          Tottenham    33.0
# 14           Chelsea    33.0
# 8            Everton    33.0
# 16       Aston Villa    32.0
# 11           Arsenal    31.0
# 9              Leeds    29.0
# 12       Southampton    29.0
# 1     Crystal Palace    26.0
# 17            Wolves    23.0
# 13         Newcastle    22.0
# 18           Burnley    22.0
# 6           Brighton    21.0
# 0             Fulham    14.0
# 4          West Brom    12.0
# 7   Sheffield United     8.0

# %%
df_burnley = df_burnley.set_index('Date')

df_burnley
# Out:
#                HomeTeam          AwayTeam  HG  AG Winner  Points
# Date
# 09-20-2020    Leicester           Burnley   4   2      H     0.0
# 09-26-2020      Burnley       Southampton   0   1      A     0.0
# 10-03-2020    Newcastle           Burnley   3   1      H     0.0
# 10-19-2020    West Brom           Burnley   0   0      D     1.0
# 10-26-2020      Burnley         Tottenham   0   1      A     0.0
# 10-31-2020      Burnley           Chelsea   0   3      A     0.0
# 11-06-2020     Brighton           Burnley   0   0      D     1.0
# 11-23-2020      Burnley    Crystal Palace   1   0      H     3.0
# 11-28-2020     Man City           Burnley   5   0      H     0.0
# 12-05-2020      Burnley           Everton   1   1      D     1.0
# 12-13-2020      Arsenal           Burnley   0   1      A     3.0
# 12-17-2020  Aston Villa           Burnley   0   0      D     1.0
# 12-21-2020      Burnley            Wolves   2   1      H     3.0
# ...

# %%
df_burnley['TotalPoints'] = df_burnley['Points'].cumsum()

# %%
df_burnley['TotalPoints'].plot()

# %%
df_wolves = df_wolves.set_index('Date')
df_wolves['TotalPoints'] = df_wolves['Points'].cumsum()
df_av = df_av.set_index('Date')
df_av['TotalPoints'] = df_av['Points'].cumsum()
df_leicester = df_leicester.set_index('Date')
df_leicester['TotalPoints'] = df_leicester['Points'].cumsum()
df_chelsea = df_chelsea.set_index('Date')
df_chelsea['TotalPoints'] = df_chelsea['Points'].cumsum()
df_newcastle = df_newcastle.set_index('Date')
df_newcastle['TotalPoints'] = df_newcastle['Points'].cumsum()
df_soton = df_soton.set_index('Date')
df_soton['TotalPoints'] = df_soton['Points'].cumsum()
df_arsenal = df_arsenal.set_index('Date')
df_arsenal['TotalPoints'] = df_arsenal['Points'].cumsum()
df_manu = df_manu.set_index('Date')
df_manu['TotalPoints'] = df_manu['Points'].cumsum()
df_leeds = df_leeds.set_index('Date')
df_leeds['TotalPoints'] = df_leeds['Points'].cumsum()
df_everton = df_everton.set_index('Date')
df_everton['TotalPoints'] = df_everton['Points'].cumsum()
df_sheffield = df_sheffield.set_index('Date')
df_sheffield['TotalPoints'] = df_sheffield['Points'].cumsum()
df_brighton = df_brighton.set_index('Date')
df_brighton['TotalPoints'] = df_brighton['Points'].cumsum()
df_wb = df_wb.set_index('Date')
df_wb['TotalPoints'] = df_wb['Points'].cumsum()
df_wh = df_wh.set_index('Date')
df_wh['TotalPoints'] = df_wh['Points'].cumsum()
df_liverpool = df_liverpool.set_index('Date')
df_liverpool['TotalPoints'] = df_liverpool['Points'].cumsum()
df_cp = df_cp.set_index('Date')
df_cp['TotalPoints'] = df_cp['Points'].cumsum()
df_fulham = df_fulham.set_index('Date')
df_fulham['TotalPoints'] = df_fulham['Points'].cumsum()
df_mancity = df_mancity.set_index('Date')
df_mancity['TotalPoints'] = df_mancity['Points'].cumsum()
df_tottenham = df_tottenham.set_index('Date')
df_tottenham['TotalPoints'] = df_tottenham['Points'].cumsum()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

sns.set(font_scale=1.5)
sns.set_style("ticks")

fig, ax = plt.subplots(figsize=(12, 8))
ax.plot(df_tottenham.index.values,
       df_tottenham['TotalPoints'].values,
       '-o',
       color='blue')

plt.xticks(rotation=90)

ax.set(xlabel="Date", ylabel='Points',
      title='Spurs Points Throughout Season')

plt.show()

# %%
for frame in [df_tottenham, df_burnley]:
    plt.plot(frame['TotalPoints'])
